# %%
import os
os.listdir()
# Out:
# ['supermarkets.json',
#  'supermarkets.csv',
#  'supermarkets-semi-colons.txt',
#  'supermarket.ipynb',
#  'supermarkets.xlsx',
#  '.ipynb_checkpoints',
#  'supermarkets-commas.txt']

# %%
import pandas

# %%
df1=pandas.read_csv("supermarkets.csv")
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2=pandas.read_json("supermarkets.json")
df2
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df3=pandas.read_excel("supermarkets.xlsx",sheet_name=0)
df3
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-11-83fffe76705d> in <module>
# ----> 1 df3=pandas.read_excel("supermarkets.xlsx",sheet_name=0)
#       2 df3
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# ...

# %%
df3=pandas.read_excel("supermarkets.xlsx",sheet_name=0)
df3
# Out:
# ---------------------------------------------------------------------------
# XLRDError                                 Traceback (most recent call last)
# <ipython-input-12-83fffe76705d> in <module>
# ----> 1 df3=pandas.read_excel("supermarkets.xlsx",sheet_name=0)
#       2 df3
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# ...

# %%
df3=pandas.read_excel("supermarkets.xlsx",sheet_name=0)
df3
# Out:
# ---------------------------------------------------------------------------
# XLRDError                                 Traceback (most recent call last)
# <ipython-input-13-83fffe76705d> in <module>
# ----> 1 df3=pandas.read_excel("supermarkets.xlsx",sheet_name=0)
#       2 df3
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# ...

# %%
df3=pandas.read_excel("supermarkets.xlsx",sheet_name=0,engine=‘openpyxl’)
df3
# Out:
#   File "<ipython-input-14-15b6fe54b1d7>", line 1
#     df3=pandas.read_excel("supermarkets.xlsx",sheet_name=0,engine=‘openpyxl’)
#                                                                            ^
# SyntaxError: invalid character in identifier

# %%
df3=pandas.read_excel("supermarkets.xlsx",sheet_name=0,engine="openpyxl")
df3
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df4=pandas.read_csv("supermarkets-semi-colons.txt")
df4
# Out:
#         ID;Address;City;State;Country;Name;Employees
# 0  1;3666 21st St;San Francisco;CA 94114;USA;Made...
# 1  2;735 Dolores St;San Francisco;CA 94119;USA;Br...
# 2  3;332 Hill St;San Francisco;California 94114;U...
# 3  4;3995 23rd St;San Francisco;CA 94114;USA;Ben'...
# 4  5;1056 Sanchez St;San Francisco;California;USA...
# 5  6;551 Alvarado St;San Francisco;CA 94114;USA;R...

# %%
df4=pandas.read_csv("supermarkets-semi-colons.txt",sep=";")
df4
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5=pandas.read_csv("supermarkets-commas.txt")
df5
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
pandas.read_csv?

# %%
import geopy
dir(geopy)
# Out:
# ['AlgoliaPlaces',
#  'ArcGIS',
#  'AzureMaps',
#  'BANFrance',
#  'Baidu',
#  'BaiduV3',
#  'Bing',
#  'DataBC',
#  'GeoNames',
#  'GeocodeEarth',
#  'Geocodio',
#  'Geolake',
#  'GoogleV3',
#  'Here',
#  'HereV7',
#  'IGNFrance',
#  'LiveAddress',
#  'Location',
#  'MapBox',
#  'MapQuest',
#  'MapTiler',
#  'Nominatim',
#  'OpenCage',
#  'OpenMapQuest',
#  'Pelias',
#  'Photon',
#  'PickPoint',
#  'Point',
#  'Timezone',
#  'TomTom',
#  'What3Words',
#  'What3WordsV3',
#  'Yandex',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '__version_info__',
#  'adapters',
#  'compat',
#  'exc',
#  'format',
#  'geocoders',
#  'get_geocoder_for_service',
#  'get_version',
#  'location',
#  'point',
#  'timezone',
#  'units',
#  'util']

# %%
from geopy.geocoders import ArcGIS
nom=ArcGIS()

# %%
nom.geocode("3995 23rd St,San Francisco,CA 94114")
# Out:
# Location(3995 23rd St, San Francisco, California, 94114, (37.75292099814533, -122.43170295955227, 0.0))

# %%
n=nom.geocode("3995 23rd St,San Francisco,CA 94114")
n.latitude
# Out:
# 37.75292099814533

# %%
type(n)
# Out:
# geopy.location.Location

# %%
import pandas
df=pandas.read_csv("supermarkets.csv")
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df["Address"]=df["Address"]+" , "+df["City"] + " , "+ df["State"]+ " , " + df["Country"]
df
# Out:
#    ID                                            Address           City  \
# 0   1      3666 21st St , San Francisco , CA 94114 , USA  San Francisco
# 1   2    735 Dolores St , San Francisco , CA 94119 , USA  San Francisco
# 2   3  332 Hill St , San Francisco , California 94114...  San Francisco
# 3   4      3995 23rd St , San Francisco , CA 94114 , USA  San Francisco
# 4   5  1056 Sanchez St , San Francisco , California ,...  San Francisco
# 5   6   551 Alvarado St , San Francisco , CA 94114 , USA  San Francisco
#
#               State Country         Name  Employees
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20

# %%
df["Coordinates"]=df["Address"].apply(geocode)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-0dd796365a9b> in <module>
# ----> 1 df["Coordinates"]=df["Address"].apply(geocode)
#       2 df
#
# NameError: name 'geocode' is not defined

# %%
df["Coordinates"]=df["Address"].apply(nom.geocode)
df
# Out:
#    ID                                            Address           City  \
# 0   1      3666 21st St , San Francisco , CA 94114 , USA  San Francisco
# 1   2    735 Dolores St , San Francisco , CA 94119 , USA  San Francisco
# 2   3  332 Hill St , San Francisco , California 94114...  San Francisco
# 3   4      3995 23rd St , San Francisco , CA 94114 , USA  San Francisco
# 4   5  1056 Sanchez St , San Francisco , California ,...  San Francisco
# 5   6   551 Alvarado St , San Francisco , CA 94114 , USA  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates
# ...

# %%
df.Coordinates
# Out:
# 0    (3666 21st St, San Francisco, California, 9411...
# 1    (735 Dolores St, San Francisco, California, 94...
# 2    (332 Hill St, San Francisco, California, 94114...
# 3    (3995 23rd St, San Francisco, California, 9411...
# 4    (1056 Sanchez St, San Francisco, California, 9...
# 5    (551 Alvarado St, San Francisco, California, 9...
# Name: Coordinates, dtype: object

# %%
df.Coordinates[0].latitude
# Out:
# 37.756632001957215

# %%
df["latitude"]=df["Coordinates"].apply(lambda x: x.latitude if x !=None else None)
df["longitude"]=df["Coordinates"].apply(lambda x: x.longitude if x !=None else None)
df
# Out:
#    ID                                            Address           City  \
# 0   1      3666 21st St , San Francisco , CA 94114 , USA  San Francisco
# 1   2    735 Dolores St , San Francisco , CA 94119 , USA  San Francisco
# 2   3  332 Hill St , San Francisco , California 94114...  San Francisco
# 3   4      3995 23rd St , San Francisco , CA 94114 , USA  San Francisco
# 4   5  1056 Sanchez St , San Francisco , California ,...  San Francisco
# 5   6   551 Alvarado St , San Francisco , CA 94114 , USA  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates   latitude   longitude
# ...

# %%
import pandas
df=pandas.read_csv("supermarkets.csv")
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df8=pandas.read_csv("supermarkets.csv")
df8
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df8.columns = ["ID","Address","City","State","Country","Name","Employees"]
df8
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df8.set_index("ID")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-fc1bb88df7fe> in <module>
# ----> 1 df8.set_index("ID")
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4548
#    4549         if missing:
# -> 4550             raise KeyError(f"None of {missing} are in the columns")
#    4551
#    4552         if inplace:
#
# KeyError: "None of ['ID'] are in the columns"

# %%
df9=df8.set_index("ID")
df9

# %%
df9=df8.set_index("Address")
df9
# Out:
#                           City             State Country         Name  \
# Address
# 3666 21st St     San Francisco          CA 94114     USA      Madeira
# 332 Hill St      San Francisco  California 94114     USA  Super River
# 1056 Sanchez St  San Francisco        California     USA      Sanchez
# 551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 332 Hill St             25
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df9["Continent"]=df9.shape[0]*["North America"]
df9
# Out:
#                           City             State Country         Name  \
# Address
# 3666 21st St     San Francisco          CA 94114     USA      Madeira
# 332 Hill St      San Francisco  California 94114     USA  Super River
# 1056 Sanchez St  San Francisco        California     USA      Sanchez
# 551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees      Continent
# Address
# 3666 21st St             8  North America
# 332 Hill St             25  North America
# 1056 Sanchez St         12  North America
# 551 Alvarado St         20  North America

# %%
len(df9.index)
# Out:
# 4

# %%
df.shape
# Out:
# (6, 7)

# %%
df9.shape
# Out:
# (4, 6)

# %%
df9.shape[0]*["North America"]
# Out:
# ['North America', 'North America', 'North America', 'North America']

# %%
df9["Continent"]=df9["Country"]+"," + "North America"
df9
# Out:
#                           City             State Country         Name  \
# Address
# 3666 21st St     San Francisco          CA 94114     USA      Madeira
# 332 Hill St      San Francisco  California 94114     USA  Super River
# 1056 Sanchez St  San Francisco        California     USA      Sanchez
# 551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees          Continent
# Address
# 3666 21st St             8  USA,North America
# 332 Hill St             25  USA,North America
# 1056 Sanchez St         12  USA,North America
# 551 Alvarado St         20  USA,North America

# %%
df9_t=df9.T

# %%
df9_t
# Out:
# Address         3666 21st St        332 Hill St    1056 Sanchez St  \
# City           San Francisco      San Francisco      San Francisco
# State               CA 94114   California 94114         California
# Country                  USA                USA                USA
# Name                 Madeira        Super River            Sanchez
# Employees                  8                 25                 12
# Continent  USA,North America  USA,North America  USA,North America
#
# Address      551 Alvarado St
# City           San Francisco
# State               CA 94114
# Country                  USA
# Name              Richvalley
# Employees                 20
# Continent  USA,North America

# %%
df9_t["new column"]=["A","B",9,8,"C","D"]

# %%
df9=df9_t.T

# %%
df9
# Out:
#                           City             State Country         Name  \
# Address
# 3666 21st St     San Francisco          CA 94114     USA      Madeira
# 332 Hill St      San Francisco  California 94114     USA  Super River
# 1056 Sanchez St  San Francisco        California     USA      Sanchez
# 551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
# new column                   A                 B       9            8
#
#                 Employees          Continent
# Address
# 3666 21st St            8  USA,North America
# 332 Hill St            25  USA,North America
# 1056 Sanchez St        12  USA,North America
# 551 Alvarado St        20  USA,North America
# new column              C                  D

# %%
df9_t
# Out:
# Address         3666 21st St        332 Hill St    1056 Sanchez St  \
# City           San Francisco      San Francisco      San Francisco
# State               CA 94114   California 94114         California
# Country                  USA                USA                USA
# Name                 Madeira        Super River            Sanchez
# Employees                  8                 25                 12
# Continent  USA,North America  USA,North America  USA,North America
#
# Address      551 Alvarado St new column
# City           San Francisco          A
# State               CA 94114          B
# Country                  USA          9
# Name              Richvalley          8
# Employees                 20          C
# Continent  USA,North America          D

# %%
df8.set_index("ID",inplace=True)
df8
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df8.set_index("Name",inplace=True, drop=False)
df8
# Out:
#                      Address           City             State Country  \
# Name
# Madeira         3666 21st St  San Francisco          CA 94114     USA
# Bready Shop   735 Dolores St  San Francisco          CA 94119     USA
# Super River      332 Hill St  San Francisco  California 94114     USA
# Ben's Shop      3995 23rd St  San Francisco          CA 94114     USA
# Sanchez      1056 Sanchez St  San Francisco        California     USA
# Richvalley   551 Alvarado St  San Francisco          CA 94114     USA
#
#                     Name  Employees
# Name
# Madeira          Madeira          8
# Bready Shop  Bready Shop         15
# Super River  Super River         25
# Ben's Shop    Ben's Shop         10
# Sanchez          Sanchez         12
# Richvalley    Richvalley         20

# %%
df8.iloc[1:3,1:3]
# Out:
#                       City             State
# Name
# Bready Shop  San Francisco          CA 94119
# Super River  San Francisco  California 94114

# %%
df8.iloc[3,1:4]
# Out:
# City       San Francisco
# State           CA 94114
# Country              USA
# Name: Ben's Shop, dtype: object

# %%
df8.drop("City",1)
# Out:
#                      Address             State Country         Name  Employees
# Name
# Madeira         3666 21st St          CA 94114     USA      Madeira          8
# Bready Shop   735 Dolores St          CA 94119     USA  Bready Shop         15
# Super River      332 Hill St  California 94114     USA  Super River         25
# Ben's Shop      3995 23rd St          CA 94114     USA   Ben's Shop         10
# Sanchez      1056 Sanchez St        California     USA      Sanchez         12
# Richvalley   551 Alvarado St          CA 94114     USA   Richvalley         20

# %%
df8
# Out:
#                      Address           City             State Country  \
# Name
# Madeira         3666 21st St  San Francisco          CA 94114     USA
# Bready Shop   735 Dolores St  San Francisco          CA 94119     USA
# Super River      332 Hill St  San Francisco  California 94114     USA
# Ben's Shop      3995 23rd St  San Francisco          CA 94114     USA
# Sanchez      1056 Sanchez St  San Francisco        California     USA
# Richvalley   551 Alvarado St  San Francisco          CA 94114     USA
#
#                     Name  Employees
# Name
# Madeira          Madeira          8
# Bready Shop  Bready Shop         15
# Super River  Super River         25
# Ben's Shop    Ben's Shop         10
# Sanchez          Sanchez         12
# Richvalley    Richvalley         20

# %%
df8=df8.drop("Ben's Shop",0)
df8
# Out:
#                      Address           City             State Country  \
# Name
# Madeira         3666 21st St  San Francisco          CA 94114     USA
# Super River      332 Hill St  San Francisco  California 94114     USA
# Sanchez      1056 Sanchez St  San Francisco        California     USA
# Richvalley   551 Alvarado St  San Francisco          CA 94114     USA
#
#                     Name  Employees
# Name
# Madeira          Madeira          8
# Super River  Super River         25
# Sanchez          Sanchez         12
# Richvalley    Richvalley         20

# %%
df8.drop(df8.index[0:2])
# Out:
#                     Address           City       State Country        Name  \
# Name
# Sanchez     1056 Sanchez St  San Francisco  California     USA     Sanchez
# Richvalley  551 Alvarado St  San Francisco    CA 94114     USA  Richvalley
#
#             Employees
# Name
# Sanchez            12
# Richvalley         20

# %%
df8.drop(df8.columns[0:2])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-02bf5c1926dc> in <module>
# ----> 1 df8.drop(df8.columns[0:2])
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4160                 weight  1.0     0.8
#    4161         """
# -> 4162         return super().drop(
#    4163             labels=labels,
#    4164             axis=axis,
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3882         for axis, labels in axes.items():
#    3883             if labels is not None:
# -> 3884                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3885
#    3886         if inplace:
#
# ...

# %%
df8
# Out:
#                      Address           City             State Country  \
# Name
# Madeira         3666 21st St  San Francisco          CA 94114     USA
# Super River      332 Hill St  San Francisco  California 94114     USA
# Sanchez      1056 Sanchez St  San Francisco        California     USA
# Richvalley   551 Alvarado St  San Francisco          CA 94114     USA
#
#                     Name  Employees
# Name
# Madeira          Madeira          8
# Super River  Super River         25
# Sanchez          Sanchez         12
# Richvalley    Richvalley         20

# %%
df8.drop(df8.columns[0:2],1)
# Out:
#                         State Country         Name  Employees
# Name
# Madeira              CA 94114     USA      Madeira          8
# Super River  California 94114     USA  Super River         25
# Sanchez            California     USA      Sanchez         12
# Richvalley           CA 94114     USA   Richvalley         20

# %%
df8.drop(df8.index[0:1])
# Out:
#                      Address           City             State Country  \
# Name
# Super River      332 Hill St  San Francisco  California 94114     USA
# Sanchez      1056 Sanchez St  San Francisco        California     USA
# Richvalley   551 Alvarado St  San Francisco          CA 94114     USA
#
#                     Name  Employees
# Name
# Super River  Super River         25
# Sanchez          Sanchez         12
# Richvalley    Richvalley         20

# %%
df8
# Out:
#                      Address           City             State Country  \
# Name
# Madeira         3666 21st St  San Francisco          CA 94114     USA
# Super River      332 Hill St  San Francisco  California 94114     USA
# Sanchez      1056 Sanchez St  San Francisco        California     USA
# Richvalley   551 Alvarado St  San Francisco          CA 94114     USA
#
#                     Name  Employees
# Name
# Madeira          Madeira          8
# Super River  Super River         25
# Sanchez          Sanchez         12
# Richvalley    Richvalley         20
